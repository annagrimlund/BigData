# %%
import pandas as pd
import sklearn
import numpy as np
import ast
from sklearn.preprocessing import MultiLabelBinarizer, PowerTransformer, StandardScaler
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
training = pd.read_excel('clean_train.xlsx')
testing = pd.read_excel('clean_test.xlsx')

# %%
columns = ['budget', 'genres_num','popularity', 'production_companies_num','production_countries_num', 'runtime',
                          'spoken_languages_num', 'Keywords_num', 'cast_num', 'crew_num','belongs_to_collection',  'homepage',
                          'original_language', 
                           'genres_10402', 'genres_10749', 'genres_10751',
                          'genres_10752', 'genres_10769', 'genres_10770', 'genres_12',
                          'genres_14', 'genres_16', 'genres_18', 'genres_27', 'genres_28',
                          'genres_35', 'genres_36', 'genres_37', 'genres_53', 'genres_80',
                          'genres_878', 'genres_9648', 'genres_99']
for col in columns:
    plt.scatter(training[col],training["revenue"])
    plt.xlabel(col)
    plt.ylabel("revenue")
    plt.title(col+"-revenue")
    plt.show()

# %%
logcols = ['budget', 'cast_num', 'crew_num', 'Keywords_num', 'revenue', 'popularity']
for col in logcols:
    plt.scatter(np.log1p(training[col]),np.log1p(training["revenue"]))
    plt.xlabel(col)
    plt.ylabel("revenue")
    plt.title(col+"-revenue")
    plt.show()

# %%
plt.hist(StandardScaler().fit_transform(np.log1p(training["popularity2"]+1).values.reshape(-1, 1)), bins=10)
plt.show()

# %%
plt.hist(np.log1p(testing["crew_num"]))
plt.show()

# %%
plt.hist((np.log1p(training["popularity"])))
plt.show()
